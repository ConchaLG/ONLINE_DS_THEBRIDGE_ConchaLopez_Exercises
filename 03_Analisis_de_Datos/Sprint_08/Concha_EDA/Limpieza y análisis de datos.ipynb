# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import ttest_ind, mannwhitneyu
from scipy.stats import f_oneway

# %%
df= pd.read_csv('./data/Impact_of_Remote_Work_on_Mental_Health.csv')

# %%
df.head()
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# 2                          11                         5       Medium
# 3                           8                         4         High
# 4                          12                         2         High
#
#   Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0              Depression                                No
# 1                 Anxiety                                No
# 2                 Anxiety                                No
# 3              Depression                               Yes
# 4                     NaN                               Yes
#
#   Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 0            Decrease                        1                   Unsatisfied
# 1            Increase                        3                     Satisfied
# 2           No Change                        4                   Unsatisfied
# 3            Increase                        3                   Unsatisfied
# 4            Decrease                        3                   Unsatisfied
#
#    Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                1            Weekly          Good
# 1                                2            Weekly          Good
# 2                                5               NaN          Poor
# 3                                3               NaN          Poor
# 4                                3            Weekly       Average
#
#           Region
# 0         Europe
# 1           Asia
# 2  North America
# 3         Europe
# 4  North America

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
#  11  Mental_Health_Condition            3804 non-null   object
#  12  Access_to_Mental_Health_Resources  5000 non-null   object
#  13  Productivity_Change                5000 non-null   object
#  14  Social_Isolation_Rating            5000 non-null   int64
#  15  Satisfaction_with_Remote_Work      5000 non-null   object
#  16  Company_Support_for_Remote_Work    5000 non-null   int64
#  17  Physical_Activity                  3371 non-null   object
#  18  Sleep_Quality                      5000 non-null   object
#  19  Region                             5000 non-null   object
# dtypes: int64(7), object(13)
# memory usage: 781.4+ KB

# %%
df.Mental_Health_Condition.value_counts()
# Out:
# Mental_Health_Condition
# Burnout       1280
# Anxiety       1278
# Depression    1246
# Name: count, dtype: int64

# %%
df['Mental_Health_Condition'] = df['Mental_Health_Condition'].fillna('Asymptomatic')

# %%
df.Physical_Activity.value_counts()
# Out:
# Physical_Activity
# Weekly    1755
# Daily     1616
# Name: count, dtype: int64

# %%
df['Physical_Activity'] = df['Physical_Activity'].fillna('Sedentary')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
#  11  Mental_Health_Condition            5000 non-null   object
#  12  Access_to_Mental_Health_Resources  5000 non-null   object
#  13  Productivity_Change                5000 non-null   object
#  14  Social_Isolation_Rating            5000 non-null   int64
#  15  Satisfaction_with_Remote_Work      5000 non-null   object
#  16  Company_Support_for_Remote_Work    5000 non-null   int64
#  17  Physical_Activity                  5000 non-null   object
#  18  Sleep_Quality                      5000 non-null   object
#  19  Region                             5000 non-null   object
# dtypes: int64(7), object(13)
# memory usage: 781.4+ KB

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Job_Role', 'Industry',
#        'Years_of_Experience', 'Work_Location', 'Hours_Worked_Per_Week',
#        'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
#        'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')

# %%
df.columns = ['ID_Empleado','Edad','Género','Rol_Laboral','Industria','Años_Experiencia','Ubicación_Laboral','Horas_Semana','Nº_Reuniones',
              'Calif._Equilibrio_Vida_Laboral','Nivel_de_Estrés','Cond_Salud_Mental','Acceso_Recursos_Salud_Mental','Cambio_en_la_Product.',
              'Calif._Aislamiento_Social','Satisfacción_Trabajo_Remoto','Apoyo_Empresa_para_Trab._Remoto','Actividad_Física','Calidad_del_Sueño',
              'Región']
print(df.columns)
# Out:
# Index(['ID_Empleado', 'Edad', 'Género', 'Rol_Laboral', 'Industria',
#        'Años_Experiencia', 'Ubicación_Laboral', 'Horas_Semana', 'Nº_Reuniones',
#        'Calif._Equilibrio_Vida_Laboral', 'Nivel_de_Estrés',
#        'Cond_Salud_Mental', 'Acceso_Recursos_Salud_Mental',
#        'Cambio_en_la_Product.', 'Calif._Aislamiento_Social',
#        'Satisfacción_Trabajo_Remoto', 'Apoyo_Empresa_para_Trab._Remoto',
#        'Actividad_Física', 'Calidad_del_Sueño', 'Región'],
#       dtype='object')

# %%
df.drop(['ID_Empleado', 'Ubicación_Laboral'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Edad                             5000 non-null   int64
#  1   Género                           5000 non-null   object
#  2   Rol_Laboral                      5000 non-null   object
#  3   Industria                        5000 non-null   object
#  4   Años_Experiencia                 5000 non-null   int64
#  5   Horas_Semana                     5000 non-null   int64
#  6   Nº_Reuniones                     5000 non-null   int64
#  7   Calif._Equilibrio_Vida_Laboral   5000 non-null   int64
#  8   Nivel_de_Estrés                  5000 non-null   object
#  9   Cond_Salud_Mental                5000 non-null   object
#  10  Acceso_Recursos_Salud_Mental     5000 non-null   object
#  11  Cambio_en_la_Product.            5000 non-null   object
#  12  Calif._Aislamiento_Social        5000 non-null   int64
#  13  Satisfacción_Trabajo_Remoto      5000 non-null   object
#  14  Apoyo_Empresa_para_Trab._Remoto  5000 non-null   int64
#  15  Actividad_Física                 5000 non-null   object
#  16  Calidad_del_Sueño                5000 non-null   object
#  17  Región                           5000 non-null   object
# dtypes: int64(7), object(11)
# memory usage: 703.3+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#               Edad  Años_Experiencia  Horas_Semana  Nº_Reuniones  \
# count  5000.000000       5000.000000   5000.000000   5000.000000
# mean     40.995000         17.810200     39.614600      7.559000
# std      11.296021         10.020412     11.860194      4.636121
# min      22.000000          1.000000     20.000000      0.000000
# 25%      31.000000          9.000000     29.000000      4.000000
# 50%      41.000000         18.000000     40.000000      8.000000
# 75%      51.000000         26.000000     50.000000     12.000000
# max      60.000000         35.000000     60.000000     15.000000
#
#        Calif._Equilibrio_Vida_Laboral  Calif._Aislamiento_Social  \
# count                     5000.000000                5000.000000
# mean                         2.984200                   2.993800
# std                          1.410513                   1.394615
# min                          1.000000                   1.000000
# 25%                          2.000000                   2.000000
# 50%                          3.000000                   3.000000
# 75%                          4.000000                   4.000000
# max                          5.000000                   5.000000
#
#        Apoyo_Empresa_para_Trab._Remoto
# count                      5000.000000
# mean                          3.007800
# std                           1.399046
# min                           1.000000
# 25%                           2.000000
# 50%                           3.000000
# 75%                           4.000000
# max                           5.000000

# %%
# Convertir
df['Edad'].astype(int)
df['Años_Experiencia'].astype(int)
df['Horas_Semana'].astype(int)
df['Nº_Reuniones'].astype(int)
df[['Calif._Equilibrio_Vida_Laboral', 'Calif._Aislamiento_Social', 'Apoyo_Empresa_para_Trab._Remoto']].round(2)
df
# Out:
#       Edad      Género        Rol_Laboral   Industria  Años_Experiencia  \
# 0       32  Non-binary                 HR  Healthcare                13
# 1       40      Female     Data Scientist          IT                 3
# 2       59  Non-binary  Software Engineer   Education                22
# 3       27        Male  Software Engineer     Finance                20
# 4       49        Male              Sales  Consulting                32
# ...    ...         ...                ...         ...               ...
# 4995    32        Male              Sales  Consulting                 4
# 4996    39      Female              Sales  Healthcare                27
# 4997    42      Female              Sales  Healthcare                21
# 4998    27      Female              Sales  Healthcare                26
# 4999    29        Male                 HR          IT                30
#
#       Horas_Semana  Nº_Reuniones  Calif._Equilibrio_Vida_Laboral  \
# 0               47             7                               2
# 1               52             4                               1
# 2               46            11                               5
# 3               32             8                               4
# 4               35            12                               2
# ...            ...           ...                             ...
# 4995            24             2                               5
# 4996            48            15                               1
# 4997            34             1                               4
# 4998            58             0                               5
# 4999            20            15                               1
#
#      Nivel_de_Estrés Cond_Salud_Mental Acceso_Recursos_Salud_Mental  \
# 0             Medium        Depression                           No
# 1             Medium           Anxiety                           No
# 2             Medium           Anxiety                           No
# 3               High        Depression                          Yes
# 4               High      Asymptomatic                          Yes
# ...              ...               ...                          ...
# 4995            High           Burnout                          Yes
# 4996             Low        Depression                          Yes
# 4997            High           Burnout                           No
# 4998             Low      Asymptomatic                          Yes
# 4999             Low        Depression                          Yes
#
#      Cambio_en_la_Product.  Calif._Aislamiento_Social  \
# 0                 Decrease                          1
# 1                 Increase                          3
# 2                No Change                          4
# 3                 Increase                          3
# 4                 Decrease                          3
# ...                    ...                        ...
# 4995              Decrease                          4
# 4996              Decrease                          1
# 4997              Increase                          3
# 4998              Increase                          3
# 4999             No Change                          3
#
#      Satisfacción_Trabajo_Remoto  Apoyo_Empresa_para_Trab._Remoto  \
# 0                    Unsatisfied                                1
# 1                      Satisfied                                2
# 2                    Unsatisfied                                5
# 3                    Unsatisfied                                3
# 4                    Unsatisfied                                3
# ...                          ...                              ...
# 4995                     Neutral                                1
# 4996                   Satisfied                                1
# 4997                   Satisfied                                1
# 4998                 Unsatisfied                                4
# 4999                 Unsatisfied                                5
#
#      Actividad_Física Calidad_del_Sueño         Región
# 0              Weekly              Good         Europe
# 1              Weekly              Good           Asia
# 2           Sedentary              Poor  North America
# 3           Sedentary              Poor         Europe
# 4              Weekly           Average  North America
# ...               ...               ...            ...
# 4995           Weekly           Average           Asia
# 4996        Sedentary           Average         Africa
# 4997            Daily              Poor        Oceania
# 4998            Daily           Average           Asia
# 4999        Sedentary              Poor           Asia
#
# [5000 rows x 18 columns]

# %%
df.Actividad_Física.hist()
# Out:
# <Axes: >

# %%
#Frecuencias, Moda, Absolutas, Relativas
for column in df.select_dtypes(include='object'):
    print(df[column].value_counts())
    print(df[column].mode())
    print(df[column].value_counts(normalize=True))
# Out:
# Género
# Female               1274
# Male                 1270
# Prefer not to say    1242
# Non-binary           1214
# Name: count, dtype: int64
# 0    Female
# Name: Género, dtype: object
# Género
# Female               0.2548
# Male                 0.2540
# Prefer not to say    0.2484
# Non-binary           0.2428
# Name: proportion, dtype: float64
# Rol_Laboral
# Project Manager      738
# Sales                733
# Designer             723
# HR                   716
# Software Engineer    711
# Data Scientist       696
# Marketing            683
# Name: count, dtype: int64
# 0    Project Manager
# Name: Rol_Laboral, dtype: object
# Rol_Laboral
# Project Manager      0.1476
# Sales                0.1466
# Designer             0.1446
# HR                   0.1432
# Software Engineer    0.1422
# Data Scientist       0.1392
# Marketing            0.1366
# Name: proportion, dtype: float64
# Industria
# Finance          747
# IT               746
# Healthcare       728
# Retail           726
# Education        690
# Manufacturing    683
# Consulting       680
# Name: count, dtype: int64
# 0    Finance
# Name: Industria, dtype: object
# Industria
# Finance          0.1494
# IT               0.1492
# Healthcare       0.1456
# Retail           0.1452
# Education        0.1380
# Manufacturing    0.1366
# Consulting       0.1360
# Name: proportion, dtype: float64
# Nivel_de_Estrés
# High      1686
# Medium    1669
# Low       1645
# Name: count, dtype: int64
# 0    High
# Name: Nivel_de_Estrés, dtype: object
# Nivel_de_Estrés
# High      0.3372
# Medium    0.3338
# Low       0.3290
# Name: proportion, dtype: float64
# Cond_Salud_Mental
# Burnout         1280
# Anxiety         1278
# Depression      1246
# Asymptomatic    1196
# Name: count, dtype: int64
# 0    Burnout
# Name: Cond_Salud_Mental, dtype: object
# Cond_Salud_Mental
# Burnout         0.2560
# Anxiety         0.2556
# Depression      0.2492
# Asymptomatic    0.2392
# Name: proportion, dtype: float64
# Acceso_Recursos_Salud_Mental
# No     2553
# Yes    2447
# Name: count, dtype: int64
# 0    No
# Name: Acceso_Recursos_Salud_Mental, dtype: object
# Acceso_Recursos_Salud_Mental
# No     0.5106
# Yes    0.4894
# Name: proportion, dtype: float64
# Cambio_en_la_Product.
# Decrease     1737
# No Change    1677
# Increase     1586
# Name: count, dtype: int64
# 0    Decrease
# Name: Cambio_en_la_Product., dtype: object
# Cambio_en_la_Product.
# Decrease     0.3474
# No Change    0.3354
# Increase     0.3172
# Name: proportion, dtype: float64
# Satisfacción_Trabajo_Remoto
# Unsatisfied    1677
# Satisfied      1675
# Neutral        1648
# Name: count, dtype: int64
# 0    Unsatisfied
# Name: Satisfacción_Trabajo_Remoto, dtype: object
# Satisfacción_Trabajo_Remoto
# Unsatisfied    0.3354
# Satisfied      0.3350
# Neutral        0.3296
# Name: proportion, dtype: float64
# Actividad_Física
# Weekly       1755
# Sedentary    1629
# Daily        1616
# Name: count, dtype: int64
# 0    Weekly
# Name: Actividad_Física, dtype: object
# Actividad_Física
# Weekly       0.3510
# Sedentary    0.3258
# Daily        0.3232
# Name: proportion, dtype: float64
# Calidad_del_Sueño
# Good       1687
# Poor       1685
# Average    1628
# Name: count, dtype: int64
# 0    Good
# Name: Calidad_del_Sueño, dtype: object
# Calidad_del_Sueño
# Good       0.3374
# Poor       0.3370
# Average    0.3256
# Name: proportion, dtype: float64
# Región
# Oceania          867
# Africa           860
# Europe           840
# Asia             829
# South America    827
# North America    777
# Name: count, dtype: int64
# 0    Oceania
# Name: Región, dtype: object
# Región
# Oceania          0.1734
# Africa           0.1720
# Europe           0.1680
# Asia             0.1658
# South America    0.1654
# North America    0.1554
# Name: proportion, dtype: float64

# %%
# Tendencia central
print(df.describe())
# Out:
#               Edad  Años_Experiencia  Horas_Semana  Nº_Reuniones  \
# count  5000.000000       5000.000000   5000.000000   5000.000000
# mean     40.995000         17.810200     39.614600      7.559000
# std      11.296021         10.020412     11.860194      4.636121
# min      22.000000          1.000000     20.000000      0.000000
# 25%      31.000000          9.000000     29.000000      4.000000
# 50%      41.000000         18.000000     40.000000      8.000000
# 75%      51.000000         26.000000     50.000000     12.000000
# max      60.000000         35.000000     60.000000     15.000000
#
#        Calif._Equilibrio_Vida_Laboral  Calif._Aislamiento_Social  \
# count                     5000.000000                5000.000000
# mean                         2.984200                   2.993800
# std                          1.410513                   1.394615
# min                          1.000000                   1.000000
# 25%                          2.000000                   2.000000
# 50%                          3.000000                   3.000000
# 75%                          4.000000                   4.000000
# max                          5.000000                   5.000000
#
#        Apoyo_Empresa_para_Trab._Remoto
# count                      5000.000000
# mean                          3.007800
# std                           1.399046
# min                           1.000000
# 25%                           2.000000
# 50%                           3.000000
# 75%                           4.000000
# max                           5.000000

# %%
# Boxplot
sns.boxplot(x=df['Satisfacción_Trabajo_Remoto'])
plt.show()

# %%
# IQR
Q1 = df['Calif._Equilibrio_Vida_Laboral'].quantile(0.25)
Q3 = df['Calif._Equilibrio_Vida_Laboral'].quantile(0.75)
IQR = Q3 - Q1
print(f'IQR: {IQR}')
# Out:
# IQR: 2.0

# %%
#Distribución
sns.histplot(df['Satisfacción_Trabajo_Remoto'], kde=True)
plt.show()

# %%
#Distribución
sns.histplot(df['Calif._Equilibrio_Vida_Laboral'], kde=True)
plt.show()

# %%
#p-value, chi2
categorical_vars = ['Cond_Salud_Mental', 'Actividad_Física']

for var in categorical_vars:
    contingency_table = pd.crosstab(df['Cond_Salud_Mental'], df[var])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f'Chi-cuadrado para {var}:')
    print(f'Chi2: {chi2}, p-value: {p}')
# Out:
# Chi-cuadrado para Cond_Salud_Mental:
# Chi2: 15000.0, p-value: 0.0
# Chi-cuadrado para Actividad_Física:
# Chi2: 7.817432281153041, p-value: 0.251786189217363

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Actividad_Física', y='Años_Experiencia', data=df)

plt.title('Años_Experiencia - Actividad_Física')
plt.xlabel('Actividad_Física')
plt.ylabel('Años_Experiencia')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Satisfacción_Trabajo_Remoto', y='Calif._Equilibrio_Vida_Laboral', data=df)


plt.title('Calif._Equilibrio_Vida_Laboral por Satisfacción_Trabajo_Remoto')
plt.xlabel('Satisfacción_Trabajo_Remoto')
plt.ylabel('Calif._Equilibrio_Vida_Laboral')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Rol_Laboral', y='Horas_Semana', data=df)

plt.title('Horas_Semana del Trabajador por Rol_Laboral')
plt.xlabel('Rol_Laboral')
plt.ylabel('Horas_Semana')
plt.grid(True)

plt.show()

# %%
df['Cond_Salud_Mental_grupo'] = df['Cond_Salud_Mental'].apply(lambda x: 'Transtornos psíquicos' if x in ['Depression', 'Anxiety', 'Burnout'] else 'Asymtomatic')

plt.figure(figsize=(10, 6))
sns.boxplot(x='Cond_Salud_Mental_grupo', y='Edad', data=df)
plt.title('Comparación de Edad con Cond Salud Mental')
plt.xlabel('Cond_Salud_Mental Mental')
plt.ylabel('Edad')

plt.show()

# %%
estadisticas = df.groupby('Cond_Salud_Mental_grupo')['Edad'].describe()
print(estadisticas)
# Out:
#                           count       mean        std   min   25%   50%   75%  \
# Cond_Salud_Mental_grupo
# Asymtomatic              1196.0  41.041806  11.421257  22.0  31.0  41.0  51.0
# Transtornos psíquicos    3804.0  40.980284  11.257831  22.0  31.0  41.0  51.0
#
#                           max
# Cond_Salud_Mental_grupo
# Asymtomatic              60.0
# Transtornos psíquicos    60.0

# %%
numeric_vars = ['Edad', 'Años_Experiencia', 'Horas_Semana', 'Nº_Reuniones']

for var in numeric_vars:
    group1 = df[df['Satisfacción_Trabajo_Remoto'] == 'Satisfied'][var]
    group2 = df[df['Satisfacción_Trabajo_Remoto'] == 'Unsatisfied'][var]
    t_stat, t_p = ttest_ind(group1, group2, equal_var=False)
    
    mw_stat, mw_p = mannwhitneyu(group1, group2)
    
    print(f'T-Test para {var}: t-stat: {t_stat}, p-value: {t_p}')
    print(f'Mann-Whitney U test para {var}: U-stat: {mw_stat}, p-value: {mw_p}')
# Out:
# T-Test para Edad: t-stat: 0.02272476454773784, p-value: 0.981871175161847
# Mann-Whitney U test para Edad: U-stat: 1404599.5, p-value: 0.9968234155662558
# T-Test para Años_Experiencia: t-stat: 1.8272412317918014, p-value: 0.06775243932590506
# Mann-Whitney U test para Años_Experiencia: U-stat: 1455640.5, p-value: 0.06775579345140752
# T-Test para Horas_Semana: t-stat: -0.21642808956576906, p-value: 0.8286672516188661
# Mann-Whitney U test para Horas_Semana: U-stat: 1398016.5, p-value: 0.8172901381329248
# T-Test para Nº_Reuniones: t-stat: -1.49885742605532, p-value: 0.1340048676082028
# Mann-Whitney U test para Nº_Reuniones: U-stat: 1362506.5, p-value: 0.13324401549937986

# %%
grupos_validos = df['Cond_Salud_Mental'].value_counts().index.tolist()

#ANOVA
datos_grupos = [df[df['Cond_Salud_Mental'] == grupo]['Edad'] for grupo in grupos_validos]

# ANOVA dos grupos
if len(datos_grupos) > 1:
    anova_results = f_oneway(*datos_grupos)
    print(f'ANOVA: F-stat: {anova_results.statistic}, p-value: {anova_results.pvalue}')
else:
    print('No hay suficientes grupos para realizar ANOVA.')
# Out:
# ANOVA: F-stat: 0.14415166137895274, p-value: 0.9334541995518612

# %%
#Contingencia
contingency_table = pd.crosstab(df['Género'], df['Rol_Laboral'])
print(contingency_table)

contingency_table = pd.crosstab(df['Cond_Salud_Mental'], df['Actividad_Física'])
print(contingency_table)
# Out:
# Rol_Laboral        Data Scientist  Designer   HR  Marketing  Project Manager  \
# Género
# Female                        204       182  179        171              170
# Male                          161       171  179        192              200
# Non-binary                    156       192  156        162              179
# Prefer not to say             175       178  202        158              189
#
# Rol_Laboral        Sales  Software Engineer
# Género
# Female               193                175
# Male                 182                185
# Non-binary           185                184
# Prefer not to say    173                167
# Actividad_Física   Daily  Sedentary  Weekly
# Cond_Salud_Mental
# Anxiety              417        381     480
# Asymptomatic         394        402     400
# Burnout              406        426     448
# Depression           399        420     427

# %%
#Pearson
correlation_matrix = df[numeric_vars].corr(method='pearson')
print(correlation_matrix)
# Out:
#                       Edad  Años_Experiencia  Horas_Semana  Nº_Reuniones
# Edad              1.000000         -0.004480     -0.001352      0.003617
# Años_Experiencia -0.004480          1.000000     -0.018537      0.019043
# Horas_Semana     -0.001352         -0.018537      1.000000     -0.004609
# Nº_Reuniones      0.003617          0.019043     -0.004609      1.000000

# %%
X = df[['Edad', 'Años_Experiencia', 'Horas_Semana']]
y = df['Calif._Equilibrio_Vida_Laboral']

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     Calif._Equilibrio_Vida_Laboral   R-squared:                       0.000
# Model:                                        OLS   Adj. R-squared:                 -0.000
# Method:                             Least Squares   F-statistic:                    0.5283
# Date:                            Tue, 17 Dec 2024   Prob (F-statistic):              0.663
# Time:                                    17:39:52   Log-Likelihood:                -8813.2
# No. Observations:                            5000   AIC:                         1.763e+04
# Df Residuals:                                4996   BIC:                         1.766e+04
# Df Model:                                       3
# Covariance Type:                        nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                2.8849      0.107     26.941      0.000       2.675       3.095
# Edad                 0.0022      0.002      1.252      0.211      -0.001       0.006
# Años_Experiencia     0.0003      0.002      0.127      0.899      -0.004       0.004
# Horas_Semana         0.0001      0.002      0.062      0.951      -0.003       0.003
# ==============================================================================
# Omnibus:                    12008.650   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              343.635
# Skew:                           0.008   Prob(JB):                     2.40e-75
# Kurtosis:                       1.716   Cond. No.                         326.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.scatterplot(data=df, x='Edad', y='Calidad_del_Sueño', hue='Género', alpha=0.6)
plt.title('Relación entre Edad, Calidad del Sueño y Género')
plt.show()

# %%
cambios_pais_industria = df.groupby(['Industria', 'Cambio_en_la_Product.', 'Región']).size().unstack(fill_value=0)

cambios_pais_industria.plot(kind='bar', stacked=True)
plt.title('Producción por país e industria')
plt.show()

# %%
cambios_pais_industria = df.groupby(['Industria', 'Cambio_en_la_Product.', 'Región']).size().unstack(fill_value=0)

#Tonos de verde
green_colors = plt.cm.Greens(range(0, 256, 256 // cambios_pais_industria.shape[1]))

#Figura y fondo transparente
fig, ax = plt.subplots()
ax = cambios_pais_industria.plot(kind='barh', stacked=True, color=green_colors, ax=ax)

# Título y etiquetas
plt.title('')
plt.xlabel('Producción') 
plt.ylabel('') 

# Leyenda de la gráfica en la parte superior derecha
plt.legend(title='Región', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., framealpha=0)

# Limpiar los ejes
ax.set_xticklabels([])
ax.set_yticklabels([])

# Establecer fondo transparente
fig.patch.set_alpha(0) 
ax.set_facecolor('none') 

plt.show()

# %%
sns.scatterplot(data=df, x='Calif._Aislamiento_Social', y='Rol_Laboral', hue='Actividad_Física', alpha=0.6)
plt.title('Calif._Aislamiento_Social, Rol_Laboral y Actividad_Física')
plt.show()

# %%
sns.pairplot(df[['Edad', 'Calif._Equilibrio_Vida_Laboral', 'Calif._Aislamiento_Social']])
plt.suptitle('Edad, Calif._Equilibrio_Vida_Laboral y Calif._Aislamiento_Social', y=1.02)
plt.show()

# %%
# Agrupar por género
grouped_df = df.groupby('Género')['Calif._Equilibrio_Vida_Laboral'].mean().reset_index()

# Gráfica de barras
plt.figure(figsize=(10, 6))
plt.barh(grouped_df['Género'], grouped_df['Calif._Equilibrio_Vida_Laboral'], color='green')  
plt.xlabel('')
plt.ylabel('')
plt.title('')
plt.grid(axis='x')

#Fondo de la figura a transparente
plt.gcf().patch.set_alpha(0) 
plt.gca().patch.set_alpha(0) 

plt.show()

# %%
# Calcular el promedio de Edad por Actividad Física
edad_promedio = df.groupby('Actividad_Física')['Edad'].mean().reset_index()

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
plt.bar(edad_promedio['Actividad_Física'], edad_promedio['Edad'], color='green', alpha=0.7)  # alpha para la transparencia

# Quitar las líneas del fondo
plt.grid(False)

# Etiquetas y título
plt.xlabel('')
plt.ylabel('Edad Promedio')
plt.title('')
plt.xticks(rotation=45)

# Quitar los números del eje y
plt.yticks([])

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
# Calcular 'Calif._Aislamiento_Social' por 'Cambio_en_la_Product.'
aislamiento_promedio = df.groupby('Cambio_en_la_Product.')['Calif._Aislamiento_Social'].mean().reset_index()

# Crear la gráfica
plt.figure(figsize=(10, 6), facecolor='none')  # Fondo de la figura transparente
plt.bar(aislamiento_promedio['Cambio_en_la_Product.'], aislamiento_promedio['Calif._Aislamiento_Social'], color='green')

# Etiquetas y título
plt.xlabel('')
plt.ylabel('Calificación de Aislamiento Social')
plt.title('')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Fondo transparente
plt.gca().patch.set_alpha(0.0) 
plt.yticks([])

plt.tight_layout()
plt.show()

# %%
# Agrupar por condición de salud mental y edad
grouped_df = df.groupby('Cond_Salud_Mental')['Edad'].mean().reset_index()

# Gráfica de barras
plt.figure(figsize=(10, 6))
plt.barh(grouped_df['Cond_Salud_Mental'], grouped_df['Edad'], color='green')  
plt.xlabel('Condición Salud Mental')  
plt.ylabel('Edad') 
plt.title('')

# Eliminar números de los ejes
plt.xticks([])
plt.yticks([])

# Fondo transparente
plt.gca().set_facecolor('none')
plt.gcf().patch.set_alpha(0.0) 

plt.grid(axis='x')
plt.show()

# %%
df.Cond_Salud_Mental.hist()
# Out:
# <Axes: >

# %%
df.Rol_Laboral.hist()
# Out:
# <Axes: >

# %%
# Gráfico de dispersión
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='Edad', y='Nivel_de_Estrés', hue='Cond_Salud_Mental', size='Nº_Reuniones', sizes=(20, 200), alpha=0.6, palette='deep')
plt.title('Análisis Multivariante: Edad, Condición de Salud Mental y Nivel de Estrés')
plt.xlabel('Edad')
plt.ylabel('Nivel de Estrés')
plt.legend(title='Condición de Salud Mental', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
scatter_plot = sns.scatterplot(data=df, 
                                x='Años_Experiencia', 
                                y='Horas_Semana', 
                                hue='Cond_Salud_Mental', 
                                palette='deep', 
                                alpha=0.7)

#Títulos y etiquetas
plt.title('Relación entre Años de Experiencia, Horas de Trabajo a la Semana y Condición de Salud Mental', fontsize=16)
plt.xlabel('Años de Experiencia', fontsize=14)
plt.ylabel('Horas de Trabajo a la Semana', fontsize=14)
plt.legend(title='Condición de Salud Mental')
plt.grid(True)

plt.show()

# %%
# Calcular 'Horas_Semana' por 'Años_Experiencia'
horas_promedio = df.groupby('Años_Experiencia')['Horas_Semana'].mean().reset_index()

#Gráfica de barras
plt.figure(figsize=(10, 6))
plt.bar(horas_promedio['Años_Experiencia'], horas_promedio['Horas_Semana'], color='green')

# Títulos
plt.xlabel('Años de Experiencia')
plt.ylabel('Horas por Semana')
plt.title('')
plt.xticks(rotation=45)

# Eliminar números de los ejes
plt.xticks([])
plt.yticks([])
plt.grid(axis='y')

# Figura transparente
plt.gcf().patch.set_alpha(0.0)
plt.gca().patch.set_alpha(0.0) 

plt.tight_layout()
plt.show()

# %%
# Contar la cantidad de empleados en cada condición de salud mental
cond_count = df['Cond_Salud_Mental'].value_counts()

# Lista de colores en tonos verdes
green_colors = ['#4CAF50', '#66BB6A', '#8BC34A', '#A5D6A7', '#C8E6C9'] 

# Gráfico circular
plt.figure(figsize=(8, 8))
plt.pie(cond_count, labels=cond_count.index, autopct='%1.1f%%', startangle=140, colors=green_colors)

# Leyenda externa con fondo transparente
plt.legend(cond_count.index, title="Condición de Salud Mental", loc='upper right', bbox_to_anchor=(1.3, 1), framealpha=0)

# Título del gráfico
plt.title('')

# Fondo transparente
plt.gca().set_facecolor('none')
plt.gcf().patch.set_alpha(0.0)  

plt.show()

# %%
# Agrupar por condición de salud mental y calcular la media de la edad
grouped_df = df.groupby('Rol_Laboral')['Horas_Semana'].mean().reset_index()

# Gráfica de barras
plt.figure(figsize=(10, 6))
plt.barh(grouped_df['Rol_Laboral'], grouped_df['Horas_Semana'], color='green')  
plt.xlabel('Rol Laboral')  
plt.ylabel('Horas Semanales') 
plt.title('')

plt.xticks([])
plt.yticks([])

# Fondo transparente
plt.gca().set_facecolor('none')
plt.gcf().patch.set_alpha(0.0) 

plt.grid(axis='x')
plt.show()
